# %%
import numpy as np
from basis import e_basis, e_tilde
import matplotlib.pyplot as plt
from data import *

# %%
t = np.arange(0,5, 0.1)

for base in e_basis:
    base = np.vectorize(base)
    plt.plot(t, base(t))

# %%
for i in range(1,5):
    plt.plot(t, np.array([e_tilde(time,i) for time in t]), label=f"e_tilde_{i}")
plt.legend()

# %%
t = 1 / 12
partition = np.linspace(0, 1, 100)
yt = generate(t, partition)
ic(yt.shape)
for i in range(6):
    plt.plot(yt[i])
# Out:
# ic| yt.shape: (1000, 100)
